# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import cross_val_score

from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

from sklearn.model_selection import GridSearchCV

from sklearn.tree import export_text

# %%
df.drop_duplicates()
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
df.booking_status.unique()
# Out:
# array(['Not_Canceled', 'Canceled'], dtype=object)

# %%
df['booking_status'] = df['booking_status'].map({'Canceled':0, 'Not_Canceled':1})

# %%
df.corr()
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.019787
# no_of_children                           -0.019787        1.000000
# no_of_weekend_nights                      0.103316        0.029478
# no_of_week_nights                         0.105622        0.024398
# required_car_parking_space                0.011429        0.034244
# lead_time                                 0.097287       -0.047091
# arrival_year                              0.076719        0.045983
# arrival_month                             0.021841       -0.003076
# arrival_date                              0.026338        0.025482
# repeated_guest                           -0.192277       -0.036348
# no_of_previous_cancellations             -0.047426       -0.016390
# no_of_previous_bookings_not_canceled     -0.119166       -0.021189
# avg_price_per_room                        0.296886        0.337728
# ...

# %%
df=df[['lead_time', 'arrival_year','repeated_guest', 'avg_price_per_room', 'no_of_special_requests', 'booking_status']]

# %%
df.isnull().sum()
# Out:
# lead_time                 0
# arrival_year              0
# repeated_guest            0
# avg_price_per_room        0
# no_of_special_requests    0
# booking_status            0
# dtype: int64

# %%
df.booking_status.value_counts()
# Out:
# 1    24390
# 0    11885
# Name: booking_status, dtype: int64

# %%
# test train split

y = df['booking_status']

x = df.drop('booking_status',axis=1)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=0)

# %%
rndf = RandomForestClassifier(n_estimators=100, min_samples_leaf =5,max_leaf_nodes =5, max_depth=5, random_state=0)
rndf.fit(x_train, y_train)
y_pred=rndf.predict(x_test)

print('accuracy_score', accuracy_score(y_test, y_pred))
print('f1_score', f1_score(y_test, y_pred))
# Out:
# accuracy_score 0.7770835247633925
# f1_score 0.8518201807964818

# %%
r = export_text(rndf.estimators_[0], feature_names=list(df.iloc[:,:5].columns))
print(r)
# Out:
# |--- arrival_year <= 2017.50
# |   |--- class: 1.0
# |--- arrival_year >  2017.50
# |   |--- lead_time <= 151.50
# |   |   |--- no_of_special_requests <= 0.50
# |   |   |   |--- avg_price_per_room <= 105.28
# |   |   |   |   |--- class: 1.0
# |   |   |   |--- avg_price_per_room >  105.28
# |   |   |   |   |--- class: 0.0
# |   |   |--- no_of_special_requests >  0.50
# |   |   |   |--- class: 1.0
# |   |--- lead_time >  151.50
# |   |   |--- class: 0.0

# %%
rndf = RandomForestClassifier(n_estimators=100, max_depth=10,  random_state=0)
scores = cross_val_score(rndf, x, y, cv=5)
print(scores)

print((scores.mean(), scores.std()))

# %%
grid_param = {
    'n_estimators': [90,100],
    'criterion': ['gini'],
    'max_depth': range(2,7,1),
    'min_samples_leaf': range(1,7,1),
    'min_samples_split': range(1,7,1),
    'max_features': ['log2']

}

# %%
grid_search = GridSearchCV(estimator=rndf, param_grid=grid_param, cv=5, n_jobs=-1,verbose=3)

grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-c19c68151653> in <module>
#       1 grid_search = GridSearchCV(estimator=rndf, param_grid=grid_param, cv=5, n_jobs=-1,verbose=3)
#       2
# ----> 3 grid_search.fit(x_train, y_train)
#
# c:\Users\qw\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\qw\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
# ...

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 6,
#  'max_features': 'log2',
#  'min_samples_leaf': 6,
#  'min_samples_split': 2,
#  'n_estimators': 90}

# %%
# with best parametres

rndf = RandomForestClassifier(
    n_estimators=90, 
    max_depth=2, 
    criterion='gini',
    max_features='log2',
    min_samples_leaf=6, 
    min_samples_split=2, 
    random_state=0
)
rndf.fit(x_train, y_train)
y_pred=rndf.predict(x_test)

print('accuracy_score', accuracy_score(y_test, y_pred))
print('f1_score', f1_score(y_test, y_pred))
# Out:
# accuracy_score 0.769548837636681
# f1_score 0.8452615992102667
